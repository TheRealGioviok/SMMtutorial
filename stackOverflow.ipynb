# %% [markdown]
# # Stack Overflow
# Stack Overflow is one of the most popular question and answer website for both professional and entusiast programmers. Founded originally in 2008, it has grown to become the largest, most trusted online community for developers to learn, share their knowledge, and build their careers.
#
# Nowadays, Stack Overflow has been incorporated as a part of the Stack Excange network of Q&A sites with a mission to help each other. With your help, we're working together to build a library of detailed answers to every question about programming.
#
# It takes is name from the very common programming bug, called "stack overflow", where a program tries to use more memory than is available on the stack. The website's tagline is "Where Developers Learn, Share, & Build Careers".
#
# While stack overflow is a great place to learn and share knowledge, people criticize it for being a somewhat hostile place for some of its user, especially the new developers, as well as for a very aggressive moderation policy.
#
# Despite this, Stack Overflow is a name that every developer knows and uses, and it is a great place to learn and share knowledge.

# %% [markdown]
# ## Using Stack Overflow's API
# Stack Overflow has a public API that allows you to access the data on the website. It can be used to access questions, answers, users, tags, and more. The API is free to use, but anonimous requests are limited to 300 requests per day. To increase this limit, you need to register an account and get an API key, which will allow you to make 10,000 requests per day.
# Still, the API can be difficult to use to retrieve large amounts of data, as it only allows you to retrieve 100 items per request and has a backoff timer of 10 seconds per request. This means that if you want to retrieve 1000 items, you need to make 10 requests, each one waiting 10 seconds before the next one. This can be very time consuming, especially if you want to retrieve a large amount of data.
# If larger amounts of data are needed, you can use the Stack Exchange Data Explorer to retrieve the data you need. This tool allows you to write SQL queries to retrieve the data you need.

# %% [markdown]
# ### Using the API
# The API is a standard REST API, which means that you can use any HTTP client to make requests to it.
# We will be using the Python requests library to make requests to the API.

# %%
# Import necessary libraries
import requests
import json
import time

# %% [markdown]
# Now define a function that allows us to create requests to send to the API. This function will take the endpoint of the request as a parameter, and will return the response as a JSON object.

# %%
def request_to(site : str = "https://api.stackexchange.com/2.3", 
               method : str = "questions", 
               parameters : dict = {"order" : "desc", 
                                    "sort" : "activity", 
                                    "site" : "stackoverflow"}) -> dict:
    # Make the request
    response = requests.get(f"{site}/{method}", params=parameters)
    # Return the response as a dictionary
    return response.json()

# %% [markdown]
# Also define a helper function that allows us to print the JSON response in a more readable way.

# %%
def print_json(json_dict : dict) -> None:
    # Print the json dictionary in a readable format
    print(json.dumps(json_dict, indent=4))

# %% [markdown]
# Lets test what we have:

# %%
data = request_to()
print_json(data)
# Out:
# {
#     "items": [
#         {
#             "tags": [
#                 "reactjs"
#             ],
#             "owner": {
#                 "account_id": 20288629,
#                 "reputation": 1791,
#                 "user_id": 14880787,
#                 "user_type": "registered",
#                 "profile_image": "https://lh4.googleusercontent.com/-YSt5K9vGiTc/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucm51GVw9vFMGAgI58cIhJqivOUHIA/s96-c/photo.jpg?sz=256",
#                 "display_name": "Manishkumar Adesara",
#                 "link": "https://stackoverflow.com/users/14880787/manishkumar-adesara"
#             },
#             "is_answered": true,
#             "view_count": 156999,
#             "answer_count": 21,
#             "score": 159,
#             "last_activity_date": 1668424365,
#             "creation_date": 1639593476,
#             "last_edit_date": 1647330693,
#             "question_id": 70368760,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/70368760/react-uncaught-referenceerror-process-is-not-defined",
#             "title": "React Uncaught ReferenceError: process is not defined"
#         },
#         {
#             "tags": [
#                 "r",
#                 "dataframe"
#             ],
#             "owner": {
#                 "account_id": 12579176,
#                 "reputation": 3,
#                 "user_id": 9150522,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/-QQ23IigYG3A/AAAAAAAAAAI/AAAAAAAAABc/UcleHQ4NYyg/photo.jpg?sz=256",
#                 "display_name": "Ridwan Shittu",
#                 "link": "https://stackoverflow.com/users/9150522/ridwan-shittu"
#             },
#             "is_answered": false,
#             "view_count": 15,
#             "answer_count": 2,
#             "score": 0,
#             "last_activity_date": 1668424355,
#             "creation_date": 1668422015,
#             "question_id": 74430243,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430243/how-to-compare-values-of-two-table-and-return-highest-value-in-r",
#             "title": "How to compare values of two table and return highest value in r?"
#         },
#         {
#             "tags": [
#                 "android",
#                 "ios",
#                 "flutter",
#                 "dart"
#             ],
#             "owner": {
#                 "account_id": 23519760,
#                 "reputation": 1,
#                 "user_id": 17567069,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a-/AOh14GhxPWv4KQPdmo5KpxrGnxLwzdEiPxgvaTmlcuGgHw=k-s256",
#                 "display_name": "Felippe Negr&#227;o de Oliveira",
#                 "link": "https://stackoverflow.com/users/17567069/felippe-negr%c3%a3o-de-oliveira"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424354,
#             "creation_date": 1668424354,
#             "question_id": 74430739,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430739/how-can-i-verify-subscription-payment-on-in-app-purchase-on-flutter",
#             "title": "How can I verify subscription payment on In App Purchase on Flutter?"
#         },
#         {
#             "tags": [
#                 "keras",
#                 "tensorflow2.0",
#                 "sparse-matrix",
#                 "tensor",
#                 "tf.keras"
#             ],
#             "owner": {
#                 "account_id": 26923413,
#                 "reputation": 1,
#                 "user_id": 20497034,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu1In2OsB3NRLwZZn_W55PnD_rWH0fxi3mGfbGD4=k-s256",
#                 "display_name": "Lee Bruce",
#                 "link": "https://stackoverflow.com/users/20497034/lee-bruce"
#             },
#             "is_answered": false,
#             "view_count": 13,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424353,
#             "creation_date": 1668404772,
#             "last_edit_date": 1668424353,
#             "question_id": 74427381,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74427381/sparsetensorspec-object-has-no-attribute-name",
#             "title": "&#39;SparseTensorSpec&#39; object has no attribute &#39;name&#39;"
#         },
#         {
#             "tags": [
#                 "sqlite",
#                 "airflow",
#                 "airflow-2.x",
#                 "airflow-webserver"
#             ],
#             "owner": {
#                 "account_id": 14163703,
#                 "reputation": 1,
#                 "user_id": 10232221,
#                 "user_type": "registered",
#                 "profile_image": "https://lh6.googleusercontent.com/-6s1XnLJ-QlI/AAAAAAAAAAI/AAAAAAAACbg/xoB-h8GWl9k/photo.jpg?sz=256",
#                 "display_name": "Santosh Gopane",
#                 "link": "https://stackoverflow.com/users/10232221/santosh-gopane"
#             },
#             "is_answered": false,
#             "view_count": 8,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1668424352,
#             "creation_date": 1668414812,
#             "last_edit_date": 1668424352,
#             "question_id": 74428794,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74428794/continuous-unique-constraint-failed-errors",
#             "title": "Continuous &quot;UNIQUE constraint failed&quot; errors"
#         },
#         {
#             "tags": [
#                 "c++",
#                 "curl",
#                 "get"
#             ],
#             "owner": {
#                 "account_id": 1403142,
#                 "reputation": 31,
#                 "user_id": 1331548,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/c8174292149d76eeae21a7175a6b5a3b?s=256&d=identicon&r=PG",
#                 "display_name": "user1331548",
#                 "link": "https://stackoverflow.com/users/1331548/user1331548"
#             },
#             "is_answered": true,
#             "view_count": 468,
#             "answer_count": 2,
#             "score": 1,
#             "last_activity_date": 1668424346,
#             "creation_date": 1590448384,
#             "question_id": 62012186,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/62012186/using-curl-in-c-c-to-issue-a-get-http-request-with-a-data-file",
#             "title": "Using CURL in C++/C to issue a GET HTTP Request with a data file"
#         },
#         {
#             "tags": [
#                 "node.js",
#                 "mongodb"
#             ],
#             "owner": {
#                 "account_id": 1350522,
#                 "reputation": 964,
#                 "user_id": 1290335,
#                 "user_type": "registered",
#                 "accept_rate": 76,
#                 "profile_image": "https://i.stack.imgur.com/cMKL8.jpg?s=256&g=1",
#                 "display_name": "Manak Kapoor",
#                 "link": "https://stackoverflow.com/users/1290335/manak-kapoor"
#             },
#             "is_answered": true,
#             "view_count": 11873,
#             "accepted_answer_id": 19275094,
#             "answer_count": 3,
#             "score": 3,
#             "last_activity_date": 1668424340,
#             "creation_date": 1381329328,
#             "question_id": 19275033,
#             "content_license": "CC BY-SA 3.0",
#             "link": "https://stackoverflow.com/questions/19275033/mongo-sort-descending",
#             "title": "Mongo sort descending"
#         },
#         {
#             "tags": [
#                 "c#",
#                 "sqlite",
#                 "xamarin.forms",
#                 "async-await"
#             ],
#             "owner": {
#                 "account_id": 26921018,
#                 "reputation": 15,
#                 "user_id": 20495037,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/24443697bdcb8a4060f1cca4bba61c5b?s=256&d=identicon&r=PG",
#                 "display_name": "Decker Ayers",
#                 "link": "https://stackoverflow.com/users/20495037/decker-ayers"
#             },
#             "is_answered": true,
#             "view_count": 48,
#             "answer_count": 2,
#             "score": -3,
#             "last_activity_date": 1668424338,
#             "creation_date": 1668369617,
#             "last_edit_date": 1668424338,
#             "question_id": 74424306,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74424306/how-to-attach-a-tasklistt-to-a-listt",
#             "title": "How to attach a Task&lt;List&lt;T&gt;&gt; to a List&lt;T&gt;?"
#         },
#         {
#             "tags": [
#                 "mysql"
#             ],
#             "owner": {
#                 "account_id": 13073022,
#                 "reputation": 518,
#                 "user_id": 9446028,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/D5dvr.jpg?s=256&g=1",
#                 "display_name": "Dedy Puji",
#                 "link": "https://stackoverflow.com/users/9446028/dedy-puji"
#             },
#             "is_answered": false,
#             "view_count": 5,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424337,
#             "creation_date": 1668423978,
#             "question_id": 74430664,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430664/select-and-group-by-same-value-mysql",
#             "title": "select and group by same value mysql"
#         },
#         {
#             "tags": [
#                 "html",
#                 "jquery"
#             ],
#             "owner": {
#                 "account_id": 23047866,
#                 "reputation": 5,
#                 "user_id": 17165177,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a-/AOh14GjqWAtybQFh3tpeNeDWfGIUlTJwJ7pN4yCImes2=k-s256",
#                 "display_name": "Babar Hussain",
#                 "link": "https://stackoverflow.com/users/17165177/babar-hussain"
#             },
#             "is_answered": false,
#             "view_count": 7,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424336,
#             "creation_date": 1668177417,
#             "last_edit_date": 1668424336,
#             "question_id": 74404060,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74404060/show-method-not-properly-working-in-j-query",
#             "title": "Show method not properly working in j query"
#         },
#         {
#             "tags": [
#                 "c#",
#                 "wpf",
#                 "mvvm",
#                 "datagrid"
#             ],
#             "owner": {
#                 "account_id": 8124601,
#                 "reputation": 431,
#                 "user_id": 6119995,
#                 "user_type": "registered",
#                 "accept_rate": 54,
#                 "profile_image": "https://www.gravatar.com/avatar/fc6ac6626a0d0c0bd60c19006ee0664a?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Tamal Banerjee",
#                 "link": "https://stackoverflow.com/users/6119995/tamal-banerjee"
#             },
#             "is_answered": false,
#             "view_count": 17,
#             "answer_count": 1,
#             "score": -1,
#             "last_activity_date": 1668424334,
#             "creation_date": 1668418305,
#             "question_id": 74429488,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74429488/how-to-do-select-all-and-unselect-all-of-a-wpf-datagrid-on-a-button-click-using",
#             "title": "How to do select all and unselect all of a WPF datagrid on a button click using MVVM?"
#         },
#         {
#             "tags": [
#                 "android",
#                 "kotlin",
#                 "spinner",
#                 "onitemselectedlistener"
#             ],
#             "owner": {
#                 "account_id": 23847635,
#                 "reputation": 29,
#                 "user_id": 17851948,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/e377e2d57d2a489229f5ae20b2ab93bb?s=256&d=identicon&r=PG",
#                 "display_name": "Paula",
#                 "link": "https://stackoverflow.com/users/17851948/paula"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424330,
#             "creation_date": 1668424330,
#             "question_id": 74430734,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430734/how-to-retrieve-the-string-of-a-selected-item-in-spinner-outside-of-onitemselect",
#             "title": "How to retrieve the String of a selected item in spinner outside of onItemSelected method?"
#         },
#         {
#             "tags": [
#                 "outlook-2016",
#                 "microsoft-exchange"
#             ],
#             "owner": {
#                 "account_id": 26926366,
#                 "reputation": 1,
#                 "user_id": 20499865,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu0yIMIaPMlMzuvbI67y6BaeEJrInCNxW8S4gdd4=k-s256",
#                 "display_name": "Lyons Family",
#                 "link": "https://stackoverflow.com/users/20499865/lyons-family"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424328,
#             "creation_date": 1668424328,
#             "question_id": 74430733,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430733/excalimer-signature-manager-for-one-particular-user-the-signature-is-not-being",
#             "title": "excalimer signature manager - For one particular user the signature is not being deployed"
#         },
#         {
#             "tags": [
#                 "sql",
#                 "sqlite",
#                 "upsert"
#             ],
#             "owner": {
#                 "account_id": 110911,
#                 "reputation": 101,
#                 "user_id": 3265691,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/5bb37f3cdad0b52e9fc096ee60e98ccf?s=256&d=identicon&r=PG",
#                 "display_name": "arun s",
#                 "link": "https://stackoverflow.com/users/3265691/arun-s"
#             },
#             "is_answered": false,
#             "view_count": 14,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424328,
#             "creation_date": 1668403046,
#             "last_edit_date": 1668424328,
#             "question_id": 74427212,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74427212/how-to-return-ids-of-rows-with-conflicting-values",
#             "title": "How to return ids of rows with conflicting values?"
#         },
#         {
#             "tags": [
#                 "c#",
#                 "winforms",
#                 "visual-studio-2019",
#                 ".net-4.5",
#                 "elementhost"
#             ],
#             "owner": {
#                 "account_id": 1782106,
#                 "reputation": 8994,
#                 "user_id": 1624552,
#                 "user_type": "registered",
#                 "accept_rate": 60,
#                 "profile_image": "https://i.stack.imgur.com/5ixgO.jpg?s=256&g=1",
#                 "display_name": "Rodri",
#                 "link": "https://stackoverflow.com/users/1624552/rodri"
#             },
#             "is_answered": false,
#             "view_count": 5,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424319,
#             "creation_date": 1668423722,
#             "last_edit_date": 1668424319,
#             "question_id": 74430609,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430609/winforms-move-a-borderless-form-without-title-bar",
#             "title": "winforms: move a borderless form (without title bar)"
#         },
#         {
#             "tags": [
#                 "flutter",
#                 "dart",
#                 "google-maps",
#                 "flutter-navigation"
#             ],
#             "owner": {
#                 "account_id": 26289347,
#                 "reputation": 1,
#                 "user_id": 19956578,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/AItbvmnCSJg4i6-dokGEdusaaPSr2AEVRBFAnWGoKXsA=k-s256",
#                 "display_name": "pratik chauhan",
#                 "link": "https://stackoverflow.com/users/19956578/pratik-chauhan"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424317,
#             "creation_date": 1668424317,
#             "question_id": 74430732,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430732/how-to-check-whether-the-given-route-contains-in-polygon-or-not-in-google-map",
#             "title": "How to check whether the given route contains in polygon or not in Google map - Flutter"
#         },
#         {
#             "tags": [
#                 "sqlite"
#             ],
#             "owner": {
#                 "account_id": 25459493,
#                 "reputation": 113,
#                 "user_id": 19259570,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/AATXAJxE6cmaIAEniaAn1XPD_jGfLHMBMs0N-sYEEuJ1=k-s256",
#                 "display_name": "BigP",
#                 "link": "https://stackoverflow.com/users/19259570/bigp"
#             },
#             "is_answered": false,
#             "view_count": 23,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424314,
#             "creation_date": 1668379159,
#             "last_edit_date": 1668424314,
#             "question_id": 74425328,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74425328/how-to-store-large-numbers-without-losing-precision",
#             "title": "How to store large numbers without losing precision?"
#         },
#         {
#             "tags": [
#                 "youtube",
#                 "fullscreen"
#             ],
#             "owner": {
#                 "account_id": 26916989,
#                 "reputation": 11,
#                 "user_id": 20491620,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/c369b75b561b67bdad9eddd03971ad6e?s=256&d=identicon&r=PG",
#                 "display_name": "LuKo87",
#                 "link": "https://stackoverflow.com/users/20491620/luko87"
#             },
#             "is_answered": false,
#             "view_count": 20,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1668424313,
#             "creation_date": 1668335804,
#             "last_edit_date": 1668407948,
#             "question_id": 74420175,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74420175/embedded-video-vimeo-yt-fullscreen-not-available",
#             "title": "Embedded Video (Vimeo/YT) Fullscreen not available"
#         },
#         {
#             "tags": [
#                 "javascript",
#                 "html",
#                 "css"
#             ],
#             "owner": {
#                 "account_id": 3236471,
#                 "reputation": 6264,
#                 "user_id": 2730554,
#                 "user_type": "registered",
#                 "accept_rate": 80,
#                 "profile_image": "https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "mHelpMe",
#                 "link": "https://stackoverflow.com/users/2730554/mhelpme"
#             },
#             "is_answered": false,
#             "view_count": 10,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424309,
#             "creation_date": 1668423456,
#             "question_id": 74430552,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430552/table-body-not-as-wide-as-table",
#             "title": "table body not as wide as table"
#         },
#         {
#             "tags": [
#                 "javascript",
#                 "reactjs",
#                 "react-hooks",
#                 "next.js",
#                 "antd"
#             ],
#             "owner": {
#                 "account_id": 19577139,
#                 "reputation": 31,
#                 "user_id": 14326998,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/Fi7o1.jpg?s=256&g=1",
#                 "display_name": "Anchal Gupta",
#                 "link": "https://stackoverflow.com/users/14326998/anchal-gupta"
#             },
#             "is_answered": false,
#             "view_count": 44,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1668424307,
#             "creation_date": 1668152475,
#             "last_edit_date": 1668424307,
#             "question_id": 74399372,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74399372/defaultfilelist-of-antd-not-taking-custom-passed-url",
#             "title": "DefaultFileList of antd not taking custom passed Url"
#         },
#         {
#             "tags": [
#                 "python",
#                 "django",
#                 "django-models",
#                 "django-rest-framework",
#                 "django-orm"
#             ],
#             "owner": {
#                 "account_id": 21407691,
#                 "reputation": 1,
#                 "user_id": 15768581,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/fe979420f0fef52080281cd5b3474aa5?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Hamza Shah",
#                 "link": "https://stackoverflow.com/users/15768581/hamza-shah"
#             },
#             "is_answered": false,
#             "view_count": 11,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424302,
#             "creation_date": 1668422072,
#             "last_edit_date": 1668424302,
#             "question_id": 74430261,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430261/how-to-calculate-cumulative-sum-with-django-orm",
#             "title": "How to calculate cumulative sum with django ORM?"
#         },
#         {
#             "tags": [
#                 "java",
#                 "dependency-injection",
#                 "static-variables"
#             ],
#             "owner": {
#                 "account_id": 26926664,
#                 "reputation": 1,
#                 "user_id": 20499822,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/166040a50cbb08e68fe4c418c6911677?s=256&d=identicon&r=PG",
#                 "display_name": "tmrthen123",
#                 "link": "https://stackoverflow.com/users/20499822/tmrthen123"
#             },
#             "is_answered": false,
#             "view_count": 9,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424300,
#             "creation_date": 1668424181,
#             "last_edit_date": 1668424300,
#             "question_id": 74430713,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430713/when-to-use-dependency-injection-or-static-final-for-an-attribute",
#             "title": "When to use dependency injection or static final for an attribute?"
#         },
#         {
#             "tags": [
#                 "sql",
#                 "sqlite"
#             ],
#             "owner": {
#                 "account_id": 1120182,
#                 "reputation": 207,
#                 "user_id": 1108687,
#                 "user_type": "registered",
#                 "accept_rate": 25,
#                 "profile_image": "https://www.gravatar.com/avatar/782110704b1a4cff14d208c32da47495?s=256&d=identicon&r=PG",
#                 "display_name": "user1108687",
#                 "link": "https://stackoverflow.com/users/1108687/user1108687"
#             },
#             "is_answered": true,
#             "view_count": 11688,
#             "accepted_answer_id": 35876869,
#             "answer_count": 4,
#             "score": 5,
#             "last_activity_date": 1668424299,
#             "creation_date": 1457464849,
#             "last_edit_date": 1668424299,
#             "question_id": 35876171,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/35876171/how-to-get-rid-of-gaps-in-rowid-numbering-after-deleting-rows",
#             "title": "How to get rid of gaps in rowid numbering after deleting rows?"
#         },
#         {
#             "tags": [
#                 "wordpress",
#                 "google-chrome-devtools",
#                 "devtools",
#                 "mobile-website"
#             ],
#             "owner": {
#                 "account_id": 26894582,
#                 "reputation": 1,
#                 "user_id": 20472724,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu0LzxOTWwab4gjHkRIl5y929FlRMUxZ6Q8T6hAR=k-s256",
#                 "display_name": "Crypto Informer",
#                 "link": "https://stackoverflow.com/users/20472724/crypto-informer"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424297,
#             "creation_date": 1668424297,
#             "question_id": 74430729,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430729/how-to-solve-browser-errors-were-logged-to-the-console",
#             "title": "how to solve Browser errors were logged to the console?"
#         },
#         {
#             "tags": [
#                 "posixct"
#             ],
#             "owner": {
#                 "account_id": 26273814,
#                 "reputation": 1,
#                 "user_id": 19943324,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/AItbvmktq3GOGyqXksy8gAKb2y6to-vI6v_y3QeISvkh=k-s256",
#                 "display_name": "NUR S\u0130MA\u0130\u015e",
#                 "link": "https://stackoverflow.com/users/19943324/nur-s%c4%b0ma%c4%b0%c5%9e"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424289,
#             "creation_date": 1668424289,
#             "question_id": 74430728,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430728/can-not-use-the-posixct-for-this-one",
#             "title": "can not use the POSIXct for this one"
#         },
#         {
#             "tags": [
#                 "php",
#                 "angular",
#                 "localhost",
#                 "port"
#             ],
#             "owner": {
#                 "account_id": 26918659,
#                 "reputation": 11,
#                 "user_id": 20493075,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/500bc96d3352deea59de9fc25473927a?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Arian Di Donato",
#                 "link": "https://stackoverflow.com/users/20493075/arian-di-donato"
#             },
#             "is_answered": false,
#             "view_count": 21,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424288,
#             "creation_date": 1668348566,
#             "last_edit_date": 1668424288,
#             "question_id": 74421740,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74421740/proxy-conf-json-problem-localhost-php-backend",
#             "title": "proxy.conf.json problem localhost php backend"
#         },
#         {
#             "tags": [
#                 "c#",
#                 "postgresql",
#                 "enums",
#                 "npgsql"
#             ],
#             "owner": {
#                 "account_id": 2529158,
#                 "reputation": 164,
#                 "user_id": 2197813,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/5c3d7b20bf7d9abd68ee847ade29ceae?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "rosepalette",
#                 "link": "https://stackoverflow.com/users/2197813/rosepalette"
#             },
#             "is_answered": true,
#             "view_count": 6428,
#             "answer_count": 3,
#             "score": 3,
#             "last_activity_date": 1668424282,
#             "creation_date": 1598417964,
#             "last_edit_date": 1598421959,
#             "question_id": 63590759,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/63590759/c-enum-to-postgres-enum",
#             "title": "C# enum to postgres enum"
#         },
#         {
#             "tags": [
#                 "batch-file",
#                 "findstr",
#                 "forfiles"
#             ],
#             "owner": {
#                 "account_id": 3811669,
#                 "reputation": 31,
#                 "user_id": 3162308,
#                 "user_type": "registered",
#                 "accept_rate": 25,
#                 "profile_image": "https://graph.facebook.com/608758356/picture?type=large",
#                 "display_name": "user3162308",
#                 "link": "https://stackoverflow.com/users/3162308/user3162308"
#             },
#             "is_answered": false,
#             "view_count": 16,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424280,
#             "creation_date": 1668363287,
#             "last_edit_date": 1668363661,
#             "question_id": 74423523,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74423523/stop-searching-for-a-string-if-found-while-using-forfiles-command",
#             "title": "Stop searching for a string if found while using forfiles command"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pyqt",
#                 "pyqt5",
#                 "resize",
#                 "qtablewidget"
#             ],
#             "owner": {
#                 "account_id": 4260209,
#                 "reputation": 975,
#                 "user_id": 3484761,
#                 "user_type": "registered",
#                 "accept_rate": 100,
#                 "profile_image": "https://i.stack.imgur.com/wgEzO.png?s=256&g=1",
#                 "display_name": "AlQuemist",
#                 "link": "https://stackoverflow.com/users/3484761/alquemist"
#             },
#             "is_answered": true,
#             "view_count": 15903,
#             "accepted_answer_id": 51897617,
#             "answer_count": 1,
#             "score": 7,
#             "last_activity_date": 1668424279,
#             "creation_date": 1534501377,
#             "last_edit_date": 1668424279,
#             "question_id": 51893313,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/51893313/adjust-the-size-width-height-of-a-custom-qtablewidget",
#             "title": "Adjust the size (width/height) of a custom QTableWidget"
#         },
#         {
#             "tags": [
#                 "javascript",
#                 "node.js",
#                 "sqlite",
#                 "fts5"
#             ],
#             "owner": {
#                 "account_id": 19440310,
#                 "reputation": 9,
#                 "user_id": 14218843,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/e5ebd7bc9dee8f4735a75b706259c634?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Rozy",
#                 "link": "https://stackoverflow.com/users/14218843/rozy"
#             },
#             "is_answered": false,
#             "view_count": 33,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424268,
#             "creation_date": 1668244951,
#             "last_edit_date": 1668424268,
#             "question_id": 74411744,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74411744/repeated-keyword-searching",
#             "title": "Repeated keyword searching"
#         }
#     ],
#     "has_more": true,
#     "quota_max": 300,
#     "quota_remaining": 299
# }

# %% [markdown]
# As we can see, the response is a JSON object with the information about the questions.
# The response contains:
# - items: the results of the query (in our case, the questions)
# - has_more: a boolean value that indicates if there are more results to retrieve. We can use pagination to retrieve more results.
# - quota_max: the maximum number of requests you can make per day. As specified before, this is 300 for anonimous requests and 10,000 for registered requests.
# - quota_remaining: the number of requests you can still make today.
# Now let's try to use pagination. We will request the first 500 questions that are tagged with python.

# %%
data = request_to(method="questions", parameters={"order" : "desc", "site" : "stackoverflow", "tagged" : "python;"})
print_json(data)
# Out:
# {
#     "items": [
#         {
#             "tags": [
#                 "javascript",
#                 "python",
#                 "html",
#                 "django"
#             ],
#             "owner": {
#                 "account_id": 26620676,
#                 "reputation": 1,
#                 "user_id": 20239504,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/0c9e7412e0b5bade5c42040794b24097?s=256&d=identicon&r=PG",
#                 "display_name": "dragline",
#                 "link": "https://stackoverflow.com/users/20239504/dragline"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424727,
#             "creation_date": 1668424727,
#             "question_id": 74430807,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430807/creating-a-dynamic-input-field-with-django",
#             "title": "Creating a dynamic input field with Django"
#         },
#         {
#             "tags": [
#                 "python",
#                 "file-upload",
#                 "streamlit"
#             ],
#             "owner": {
#                 "account_id": 20397684,
#                 "reputation": 1,
#                 "user_id": 14964109,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/-f31VcmS7BX0/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclbDXnKcDGpNVq-QICoN1YBv_w6Cw/s96-c/photo.jpg?sz=256",
#                 "display_name": "NAGA VENKATA SRINIVAS MENTA",
#                 "link": "https://stackoverflow.com/users/14964109/naga-venkata-srinivas-menta"
#             },
#             "is_answered": false,
#             "view_count": 21,
#             "answer_count": 2,
#             "score": -1,
#             "last_activity_date": 1668424725,
#             "creation_date": 1668360326,
#             "question_id": 74423171,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74423171/streamlit-image-file-upload-to-deta-drive",
#             "title": "Streamlit image/file upload to deta drive"
#         },
#         {
#             "tags": [
#                 "python",
#                 "web-scraping",
#                 "beautifulsoup"
#             ],
#             "owner": {
#                 "account_id": 26899864,
#                 "reputation": 9,
#                 "user_id": 20477176,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu3-tGRhdh7NtLtnnyGhpYjmteuaYb3wPIBKN7C4=k-s256",
#                 "display_name": "David Jimenez",
#                 "link": "https://stackoverflow.com/users/20477176/david-jimenez"
#             },
#             "is_answered": false,
#             "view_count": 16,
#             "answer_count": 1,
#             "score": -2,
#             "last_activity_date": 1668424710,
#             "creation_date": 1668422514,
#             "last_edit_date": 1668423928,
#             "question_id": 74430358,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430358/beautifulsoup-get-text-from-tag-searching-by-title",
#             "title": "BeautifulSoup get text from tag searching by Title"
#         },
#         {
#             "tags": [
#                 "python",
#                 "excel",
#                 "pandas",
#                 "dataframe",
#                 "missing-data"
#             ],
#             "owner": {
#                 "account_id": 26920060,
#                 "reputation": 1,
#                 "user_id": 20494239,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/e8504d4fa13b109641c9ccc36ce7c668?s=256&d=identicon&r=PG",
#                 "display_name": "Juan Pa&#241;os Basterra",
#                 "link": "https://stackoverflow.com/users/20494239/juan-pa%c3%b1os-basterra"
#             },
#             "is_answered": false,
#             "view_count": 33,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424695,
#             "creation_date": 1668360321,
#             "last_edit_date": 1668424695,
#             "question_id": 74423168,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74423168/pandas-read-excel-na-values-not-working-correctly",
#             "title": "pandas.read_excel() na_values not working correctly"
#         },
#         {
#             "tags": [
#                 "python",
#                 "decorator",
#                 "mypy",
#                 "abc"
#             ],
#             "owner": {
#                 "account_id": 1197876,
#                 "reputation": 366,
#                 "user_id": 1169220,
#                 "user_type": "registered",
#                 "accept_rate": 57,
#                 "profile_image": "https://www.gravatar.com/avatar/390ca2abf506baa7dab9f2048437bf0d?s=256&d=identicon&r=PG",
#                 "display_name": "waszil",
#                 "link": "https://stackoverflow.com/users/1169220/waszil"
#             },
#             "is_answered": false,
#             "view_count": 2,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424685,
#             "creation_date": 1668424685,
#             "question_id": 74430792,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430792/mypy-throws-error-for-abstractmethod-created-with-decorator",
#             "title": "mypy throws error for abstractmethod created with decorator"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pandas",
#                 "matplotlib",
#                 "plot"
#             ],
#             "owner": {
#                 "account_id": 26888070,
#                 "reputation": 1,
#                 "user_id": 20467300,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/81eaa0d0a19f31c77035fc23d21bcccf?s=256&d=identicon&r=PG",
#                 "display_name": "hufoveconMax",
#                 "link": "https://stackoverflow.com/users/20467300/hufoveconmax"
#             },
#             "is_answered": false,
#             "view_count": 4,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424657,
#             "creation_date": 1668424657,
#             "question_id": 74430789,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430789/percentage-stacked-area-chart-from-excel-spreadsheet-with-matplotlib",
#             "title": "Percentage Stacked Area Chart from Excel Spreadsheet with matplotlib"
#         },
#         {
#             "tags": [
#                 "python",
#                 "regex"
#             ],
#             "owner": {
#                 "account_id": 20669707,
#                 "reputation": 1,
#                 "user_id": 15175742,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/86b005a3e74d3f33b8734e0cca185754?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "somequestion",
#                 "link": "https://stackoverflow.com/users/15175742/somequestion"
#             },
#             "is_answered": false,
#             "view_count": 6,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424631,
#             "creation_date": 1668424631,
#             "question_id": 74430784,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430784/python-regex-how-to-get-a-word-between-a-string-and-space",
#             "title": "Python Regex: How to get a word between a string and space?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "video",
#                 "encoding",
#                 "video-compression"
#             ],
#             "owner": {
#                 "account_id": 166832,
#                 "reputation": 1023,
#                 "user_id": 391232,
#                 "user_type": "registered",
#                 "accept_rate": 76,
#                 "profile_image": "https://i.stack.imgur.com/NYJxQ.png?s=256&g=1",
#                 "display_name": "Maverick",
#                 "link": "https://stackoverflow.com/users/391232/maverick"
#             },
#             "is_answered": false,
#             "view_count": 6,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1668424630,
#             "creation_date": 1668415074,
#             "question_id": 74428840,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74428840/bjontegaard-calculation-using-only-one-pair-of-psnr-and-bitrate",
#             "title": "Bjontegaard calculation using only one pair of PSNR and BitRate"
#         },
#         {
#             "tags": [
#                 "python",
#                 "python-3.x",
#                 "opencv",
#                 "rtsp"
#             ],
#             "owner": {
#                 "account_id": 26479135,
#                 "reputation": 19,
#                 "user_id": 20118621,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu2BbBLJ5Vdsu0FCRWQZ0uhIA4Xlgp-NfeTCug2G=k-s256",
#                 "display_name": "Bireysel Finans",
#                 "link": "https://stackoverflow.com/users/20118621/bireysel-finans"
#             },
#             "is_answered": false,
#             "view_count": 8,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424627,
#             "creation_date": 1668415580,
#             "last_edit_date": 1668424627,
#             "question_id": 74428933,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74428933/rtsp-video-record-time-delay",
#             "title": "RTSP video record time delay"
#         },
#         {
#             "tags": [
#                 "python",
#                 "math",
#                 "cv2",
#                 "mss"
#             ],
#             "owner": {
#                 "account_id": 26778945,
#                 "reputation": 21,
#                 "user_id": 20374112,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/462943a815feb3e76213daeda496e05e?s=256&d=identicon&r=PG",
#                 "display_name": "JorgTV",
#                 "link": "https://stackoverflow.com/users/20374112/jorgtv"
#             },
#             "is_answered": false,
#             "view_count": 5,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424618,
#             "creation_date": 1668424618,
#             "question_id": 74430781,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430781/how-can-i-get-the-nearest-entity-in-python",
#             "title": "How can I get the nearest entity in python"
#         },
#         {
#             "tags": [
#                 "python",
#                 "database-connection",
#                 "talend",
#                 "dbvisualizer",
#                 "exasol"
#             ],
#             "owner": {
#                 "account_id": 20504952,
#                 "reputation": 13,
#                 "user_id": 15048010,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/7cbb59f338f6647ffe7cfc86613e117d?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Josh2187",
#                 "link": "https://stackoverflow.com/users/15048010/josh2187"
#             },
#             "is_answered": false,
#             "view_count": 4,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424595,
#             "creation_date": 1668423547,
#             "question_id": 74430573,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430573/exasol-error-i-keep-getting-exasol-connection-error-timed-out",
#             "title": "Exasol_Error: I keep getting Exasol connection error timed out"
#         },
#         {
#             "tags": [
#                 "python",
#                 "api",
#                 "url"
#             ],
#             "owner": {
#                 "account_id": 26903925,
#                 "reputation": 1,
#                 "user_id": 20480621,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/bbbe3858d79825b9fb9934f41d084b8c?s=256&d=identicon&r=PG",
#                 "display_name": "Larsy",
#                 "link": "https://stackoverflow.com/users/20480621/larsy"
#             },
#             "is_answered": false,
#             "view_count": 6,
#             "closed_date": 1668424673,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1668424579,
#             "creation_date": 1668424579,
#             "question_id": 74430778,
#             "link": "https://stackoverflow.com/questions/74430778/how-do-i-make-an-url-with-variables-that-updates-according-to-the-day",
#             "closed_reason": "Duplicate",
#             "title": "How do i make an url with variables that updates according to the day?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pandas",
#                 "dataframe",
#                 "jupyter-notebook"
#             ],
#             "owner": {
#                 "account_id": 17872956,
#                 "reputation": 642,
#                 "user_id": 12985497,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/3108ae2c2e6ee10265ee981dce41e39c?s=256&d=identicon&r=PG",
#                 "display_name": "Caledonian26",
#                 "link": "https://stackoverflow.com/users/12985497/caledonian26"
#             },
#             "is_answered": true,
#             "view_count": 13,
#             "answer_count": 2,
#             "score": 0,
#             "last_activity_date": 1668424578,
#             "creation_date": 1668423890,
#             "question_id": 74430647,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430647/str-object-has-no-attribute-str-not-sure-why",
#             "title": "&#39;str&#39; object has no attribute &#39;str&#39; - not sure why"
#         },
#         {
#             "tags": [
#                 "python",
#                 "random"
#             ],
#             "owner": {
#                 "account_id": 2407603,
#                 "reputation": 176,
#                 "user_id": 2134072,
#                 "user_type": "registered",
#                 "accept_rate": 100,
#                 "profile_image": "https://www.gravatar.com/avatar/84bc3d39343e6b6559f9ba7a2c458e3a?s=256&d=identicon&r=PG",
#                 "display_name": "Clang",
#                 "link": "https://stackoverflow.com/users/2134072/clang"
#             },
#             "is_answered": false,
#             "view_count": 8,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424503,
#             "creation_date": 1668424503,
#             "question_id": 74430760,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430760/why-does-a-combined-call-to-random-randint-and-random-sample-in-a-loop-lead-to-a",
#             "title": "Why does a combined call to random.randint and random.sample in a loop lead to a repeating output sequence?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pandas",
#                 "numpy",
#                 "csv"
#             ],
#             "owner": {
#                 "account_id": 26854613,
#                 "reputation": 1,
#                 "user_id": 20439082,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu3eKHER4_c8CKFEfvYtgyXVCm1NE6pC9AB1kjet=k-s256",
#                 "display_name": "Muhammad Waseem",
#                 "link": "https://stackoverflow.com/users/20439082/muhammad-waseem"
#             },
#             "is_answered": false,
#             "view_count": 14,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424503,
#             "creation_date": 1668424129,
#             "last_edit_date": 1668424503,
#             "question_id": 74430700,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430700/how-to-set-the-value-in-columns-and-row-using-pandas",
#             "title": "How to set the value in Columns and row using Pandas"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pandas",
#                 "string",
#                 "replace"
#             ],
#             "owner": {
#                 "account_id": 26728145,
#                 "reputation": 41,
#                 "user_id": 20330965,
#                 "user_type": "registered",
#                 "profile_image": "https://lh3.googleusercontent.com/a/ALm5wu014TE-xstiXxw0cqlna0CClb8wSMsZfql1zono=k-s256",
#                 "display_name": "Nico O",
#                 "link": "https://stackoverflow.com/users/20330965/nico-o"
#             },
#             "is_answered": false,
#             "view_count": 11,
#             "answer_count": 1,
#             "score": 1,
#             "last_activity_date": 1668424772,
#             "creation_date": 1668424143,
#             "last_edit_date": 1668424499,
#             "question_id": 74430704,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430704/using-regex-in-python-to-delete-or-replace-parentheses-and-items-inside-them",
#             "title": "Using regex in python to delete (or replace) parentheses and items inside them"
#         },
#         {
#             "tags": [
#                 "python",
#                 "regex"
#             ],
#             "owner": {
#                 "account_id": 56904,
#                 "reputation": 12192,
#                 "user_id": 170431,
#                 "user_type": "registered",
#                 "accept_rate": 95,
#                 "profile_image": "https://i.stack.imgur.com/votcq.jpg?s=256&g=1",
#                 "display_name": "Ken Kinder",
#                 "link": "https://stackoverflow.com/users/170431/ken-kinder"
#             },
#             "is_answered": true,
#             "view_count": 178907,
#             "accepted_answer_id": 2136580,
#             "answer_count": 19,
#             "score": 319,
#             "last_activity_date": 1668424443,
#             "creation_date": 1264462873,
#             "last_edit_date": 1654084868,
#             "question_id": 2136556,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/2136556/in-python-how-do-i-split-a-string-and-keep-the-separators",
#             "title": "In Python, how do I split a string and keep the separators?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "bash",
#                 "csv"
#             ],
#             "owner": {
#                 "account_id": 23376008,
#                 "reputation": 178,
#                 "user_id": 17487397,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/f6f0a986fe595ab34902bd27eea01e06?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "N. J",
#                 "link": "https://stackoverflow.com/users/17487397/n-j"
#             },
#             "is_answered": false,
#             "view_count": 7,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424744,
#             "creation_date": 1668424410,
#             "question_id": 74430744,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430744/python-can-not-separate-csv-file-value-all-data-in-same-row",
#             "title": "Python - Can not separate CSV file value. All data in same row"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pandas",
#                 "dataframe"
#             ],
#             "owner": {
#                 "account_id": 18054939,
#                 "reputation": 45,
#                 "user_id": 13123654,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/93c27d99ce840880c58984a7c38f57a6?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "jhew123",
#                 "link": "https://stackoverflow.com/users/13123654/jhew123"
#             },
#             "is_answered": true,
#             "view_count": 92,
#             "accepted_answer_id": 74405517,
#             "answer_count": 1,
#             "score": 0,
#             "last_activity_date": 1668424406,
#             "creation_date": 1668095221,
#             "last_edit_date": 1668100887,
#             "question_id": 74391747,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74391747/comparing-three-data-frames-to-evaluate-multiple-criteria",
#             "title": "Comparing three data frames to evaluate multiple criteria"
#         },
#         {
#             "tags": [
#                 "python",
#                 "java",
#                 "utf-8",
#                 "base64"
#             ],
#             "owner": {
#                 "account_id": 1953240,
#                 "reputation": 455,
#                 "user_id": 1756883,
#                 "user_type": "registered",
#                 "accept_rate": 83,
#                 "profile_image": "https://www.gravatar.com/avatar/3b82eaaa37faaf310633b79711f1749f?s=256&d=identicon&r=PG",
#                 "display_name": "Scott Alexander",
#                 "link": "https://stackoverflow.com/users/1756883/scott-alexander"
#             },
#             "is_answered": false,
#             "view_count": 9,
#             "answer_count": 0,
#             "score": 2,
#             "last_activity_date": 1668424385,
#             "creation_date": 1668424385,
#             "question_id": 74430743,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430743/base64-conversion-issue-between-python-and-java",
#             "title": "Base64 Conversion issue between Python and JAVA"
#         },
#         {
#             "tags": [
#                 "python",
#                 "django",
#                 "django-models",
#                 "django-rest-framework",
#                 "django-orm"
#             ],
#             "owner": {
#                 "account_id": 21407691,
#                 "reputation": 1,
#                 "user_id": 15768581,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/fe979420f0fef52080281cd5b3474aa5?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Hamza Shah",
#                 "link": "https://stackoverflow.com/users/15768581/hamza-shah"
#             },
#             "is_answered": false,
#             "view_count": 11,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424302,
#             "creation_date": 1668422072,
#             "last_edit_date": 1668424302,
#             "question_id": 74430261,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430261/how-to-calculate-cumulative-sum-with-django-orm",
#             "title": "How to calculate cumulative sum with django ORM?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "pyqt",
#                 "pyqt5",
#                 "resize",
#                 "qtablewidget"
#             ],
#             "owner": {
#                 "account_id": 4260209,
#                 "reputation": 975,
#                 "user_id": 3484761,
#                 "user_type": "registered",
#                 "accept_rate": 100,
#                 "profile_image": "https://i.stack.imgur.com/wgEzO.png?s=256&g=1",
#                 "display_name": "AlQuemist",
#                 "link": "https://stackoverflow.com/users/3484761/alquemist"
#             },
#             "is_answered": true,
#             "view_count": 15903,
#             "accepted_answer_id": 51897617,
#             "answer_count": 1,
#             "score": 7,
#             "last_activity_date": 1668424279,
#             "creation_date": 1534501377,
#             "last_edit_date": 1668424279,
#             "question_id": 51893313,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/51893313/adjust-the-size-width-height-of-a-custom-qtablewidget",
#             "title": "Adjust the size (width/height) of a custom QTableWidget"
#         },
#         {
#             "tags": [
#                 "python",
#                 "plotly",
#                 "plotly-dash"
#             ],
#             "owner": {
#                 "account_id": 3983351,
#                 "reputation": 5027,
#                 "user_id": 3284713,
#                 "user_type": "registered",
#                 "accept_rate": 100,
#                 "profile_image": "https://www.gravatar.com/avatar/0f96b0e18df436dfccd3a204868942a0?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "CAPSLOCK",
#                 "link": "https://stackoverflow.com/users/3284713/capslock"
#             },
#             "is_answered": false,
#             "view_count": 3,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1668424261,
#             "creation_date": 1668423930,
#             "last_edit_date": 1668424261,
#             "question_id": 74430658,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430658/dash-python-server-side-vs-client-side-callback",
#             "title": "Dash python: server-side vs client-side callback"
#         },
#         {
#             "tags": [
#                 "python",
#                 "sqlite"
#             ],
#             "owner": {
#                 "account_id": 23601268,
#                 "reputation": 13,
#                 "user_id": 17637719,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/996d7364bffec11d2c4b72fe494050eb?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "StayPositive69",
#                 "link": "https://stackoverflow.com/users/17637719/staypositive69"
#             },
#             "is_answered": false,
#             "view_count": 18,
#             "answer_count": 0,
#             "score": -2,
#             "last_activity_date": 1668424257,
#             "creation_date": 1668378323,
#             "last_edit_date": 1668424257,
#             "question_id": 74425253,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74425253/synchronise-postgresql-and-sqlite-database",
#             "title": "Synchronise PostgreSQL and SQLite database"
#         },
#         {
#             "tags": [
#                 "python",
#                 "numpy",
#                 "matrix"
#             ],
#             "owner": {
#                 "account_id": 16212779,
#                 "reputation": 57,
#                 "user_id": 11706289,
#                 "user_type": "registered",
#                 "profile_image": "https://i.stack.imgur.com/Ad5Xu.png?s=256&g=1",
#                 "display_name": "Atom",
#                 "link": "https://stackoverflow.com/users/11706289/atom"
#             },
#             "is_answered": false,
#             "view_count": 10,
#             "answer_count": 1,
#             "score": -1,
#             "last_activity_date": 1668424256,
#             "creation_date": 1668423924,
#             "question_id": 74430656,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430656/how-to-find-index-in-a-matrix-using-another-list-as-a-reference-using-numpy",
#             "title": "How to find index in a matrix using another list as a reference using Numpy?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "apache",
#                 "xampp"
#             ],
#             "owner": {
#                 "account_id": 2343650,
#                 "reputation": 2517,
#                 "user_id": 2054434,
#                 "user_type": "registered",
#                 "accept_rate": 51,
#                 "profile_image": "https://www.gravatar.com/avatar/e8f5c753d781ce498b857ec9b7ce366f?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "PlayHardGoPro",
#                 "link": "https://stackoverflow.com/users/2054434/playhardgopro"
#             },
#             "is_answered": true,
#             "view_count": 77500,
#             "protected_date": 1571522297,
#             "answer_count": 5,
#             "score": 13,
#             "last_activity_date": 1668424245,
#             "creation_date": 1489091514,
#             "last_edit_date": 1592644375,
#             "question_id": 42704846,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/42704846/running-python-scripts-with-xampp",
#             "title": "Running Python scripts with Xampp"
#         },
#         {
#             "tags": [
#                 "python",
#                 "discord",
#                 "discord.py"
#             ],
#             "owner": {
#                 "account_id": 26920419,
#                 "reputation": 1,
#                 "user_id": 20494538,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/424c3d6e33d39a535b2e189c2ce6a93a?s=256&d=identicon&r=PG",
#                 "display_name": "chronic",
#                 "link": "https://stackoverflow.com/users/20494538/chronic"
#             },
#             "is_answered": false,
#             "view_count": 10,
#             "answer_count": 0,
#             "score": 0,
#             "last_activity_date": 1668424186,
#             "creation_date": 1668424186,
#             "question_id": 74430716,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430716/how-to-add-a-role-with-discord-py",
#             "title": "How to add a role with discord.py?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "sqlite",
#                 "peewee"
#             ],
#             "owner": {
#                 "account_id": 23090602,
#                 "reputation": 21,
#                 "user_id": 18073200,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/d221ed174f855f0377335079c5121b61?s=256&d=identicon&r=PG",
#                 "display_name": "denstran",
#                 "link": "https://stackoverflow.com/users/18073200/denstran"
#             },
#             "is_answered": false,
#             "view_count": 9,
#             "answer_count": 0,
#             "score": 1,
#             "last_activity_date": 1668424178,
#             "creation_date": 1668371691,
#             "last_edit_date": 1668424178,
#             "question_id": 74424559,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74424559/why-peewee-ignores-columns-unique-definition",
#             "title": "Why peewee ignores column&#39;s unique definition?"
#         },
#         {
#             "tags": [
#                 "python",
#                 "file",
#                 "glob"
#             ],
#             "owner": {
#                 "account_id": 26908677,
#                 "reputation": 1,
#                 "user_id": 20484604,
#                 "user_type": "registered",
#                 "profile_image": "https://www.gravatar.com/avatar/1fb65924f7a583c43130dc3065b05867?s=256&d=identicon&r=PG",
#                 "display_name": "pythonhelp",
#                 "link": "https://stackoverflow.com/users/20484604/pythonhelp"
#             },
#             "is_answered": false,
#             "view_count": 6,
#             "answer_count": 0,
#             "score": -1,
#             "last_activity_date": 1668424118,
#             "creation_date": 1668424118,
#             "question_id": 74430697,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430697/need-to-write-a-glob-function-to-read-4-text-files-and-then-write-an-output-file",
#             "title": "Need to write a Glob function to read 4 text files and then write an output file"
#         },
#         {
#             "tags": [
#                 "python",
#                 "sequence",
#                 "smoothing"
#             ],
#             "owner": {
#                 "account_id": 5686358,
#                 "reputation": 363,
#                 "user_id": 4495790,
#                 "user_type": "registered",
#                 "accept_rate": 33,
#                 "profile_image": "https://www.gravatar.com/avatar/f44c094862f1ce0f9e1a629a7c4b6862?s=256&d=identicon&r=PG&f=1",
#                 "display_name": "Fredrik",
#                 "link": "https://stackoverflow.com/users/4495790/fredrik"
#             },
#             "is_answered": false,
#             "view_count": 24,
#             "answer_count": 3,
#             "score": 0,
#             "last_activity_date": 1668424107,
#             "creation_date": 1668422277,
#             "question_id": 74430304,
#             "content_license": "CC BY-SA 4.0",
#             "link": "https://stackoverflow.com/questions/74430304/how-to-smooth-list-of-numerical-values-in-python",
#             "title": "How to smooth list of numerical values in Python?"
#         }
#     ],
#     "has_more": true,
#     "quota_max": 300,
#     "quota_remaining": 293
# }

# %% [markdown]
# Lets try to visualize the length of the questions:

# %%
print(len(data["items"]))
# Out:
# 30

# %% [markdown]
# This is not what we expected. In fact, we expected 100 results. We need to specify the page parameter to retrieve the next page of results.

# %%
data = request_to(method="questions", parameters={"order" : "desc", "site" : "stackoverflow", "tagged" : "python;", "pagesize" : 100})
print(len(data["items"]))
# Out:
# 100

# %% [markdown]
# Now we can finally retrieve the first 500 questions.

# %%
data = []
ELEMS = 500
ELEMPERPAGE = 100

def page_request(method : str, i : int, parameters : dict, page_size : int = 100) -> dict:
    # For sagety, notify the user if page / pagesize was already present in the parameter list
    if "page" in parameters:
        print("Page already present in parameters. Overwriting.")
    if "pagesize" in parameters:
        print("Page size already present in parameters. Overwriting.")
    parameters["page"] = i
    parameters["pagesize"] = page_size
    return request_to(method="questions", parameters=parameters)

for i in range(1, ((ELEMS + ELEMPERPAGE) //ELEMPERPAGE) ):
    data.append(page_request("questions", i, parameters={"order" : "desc", "site" : "stackoverflow", "tagged" : "python;"}))
    if "backoff" in data[-1]:
        time.sleep(data[-1]["backoff"])

# %%
print([len(data[i]) for i in range(len(data))])
print([len(data[i]["items"]) for i in range(len(data))])
# Out:
# [4, 4, 4, 4, 4]
# [100, 100, 100, 100, 100]

# %% [markdown]
# Now that we know how to access the data, lets try to do something more interesting.
# First, retrieve the first 2500 questions that are unanswered, sorted by the number of votes (descending).

# %%
data = []
ELEMS = 2500
parameters = {"order" : "desc", "site" : "stackoverflow", "unanswered" : "true"}
for i in range(1, ((ELEMS + ELEMPERPAGE) //ELEMPERPAGE) ):
    data.append(page_request("questions", i, parameters))
    if "backoff" in data[-1]:
        time.sleep(data[-1]["backoff"])

# %%
print(len(data))
# Check how many requests do we still have
print(data[24]["quota_remaining"])
# Out:
# 100
# 246
